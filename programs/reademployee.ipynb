# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/giridhar276/cgi16032026/refs/heads/main/employee.csv")

# %%
#df = pd.read_sql("select * from tablename", connectionstring)

# %%
#df = pd.read_csv("employee.csv")
#df

# %%
df

# %%
# display first 5 records only
df.head(10)  # 5 is the default

# %%
# dispilay last 5 records
df.tail(5)

# %%
# display range of records : 5th to 10th record
# df.iloc[rows, columns]
df.iloc[5:11]

# %%
# display only one particular record
df.iloc[5:6]

# %%
# df.iloc[rows , columns ]
df.iloc[5:11 , 0:3]

# %%
df.iloc[5:11 ,4:6]

# %%
# get info of the dataframe
df.info()

# %%
# just display datypes
df.dtypes

# %%
# summary( basic statistics ) of whole daframe ( default to int columns) 
df.describe()

# %%
type(df)

# %%
# display one single column
# select workclass from employee - sql type
df["workclass"]

# %%
# display unique workclasses only
df["workclass"].unique()

# %%
# display no.of unique workclasses only
df["workclass"].nunique()  # no of unique workclasses


#or
len(df["workclass"].unique())

# %%
# display the column names only
df.columns

# %%
# display multiple columns
df[['age','education']]

# %%
# write this output to a csv file
df[['age','education']].to_csv("finaloutput.csv",index=None)

# %%
df.head(40).to_csv("first40records.csv")

# %%
df['workclass']

# %%
###### conditions in pandas ############
# select * from tablename where dept = 'Sales'
# display all the records where workclass is Private
condition = df['workclass'] == " Private"
df[condition]

# %%
# or
df[df['workclass'] == " Private"]

# %%
# workclass is private and gender is female
cond1 = df['workclass'] == " Private"
cond2 = df['gender'] == " Female"

df[(cond1) & (cond2)]

# %%
# sorting dataframe based on column in ascending order 
df.sort_values('age')

# %%
# in descending order
df.sort_values('age', ascending= False)

# %%
# count no. of rows with each unique value
df['workclass'].value_counts()

# %%
### handling missing values
df.dropna()   # drop rows with any column having Null data

# %%
df.fillna(0)  # replace all null data with 0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1   workclass        32561 non-null  str
#  2   fnlwgt           32561 non-null  int64
#  3   education        32561 non-null  str
#  4   educational-num  32561 non-null  int64
#  5   marital-status   32561 non-null  str
#  6   occupation       32561 non-null  str
#  7   relationship     32561 non-null  str
#  8   race             32561 non-null  str
#  9   gender           32561 non-null  str
#  10  capital-gain     32561 non-null  int64
#  11  capital-loss     32561 non-null  int64
#  12  hours-per-week   32561 non-null  int64
#  13  native-country   32561 non-null  str
#  14  income           32561 non-null  str
# dtypes: int64(6), str(9)
# memory usage: 3.7 MB

# %%
df.isnull().sum()
